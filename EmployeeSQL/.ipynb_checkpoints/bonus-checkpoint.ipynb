# %%
# import dependencies
from sqlalchemy import create_engine
import config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# establish connection
database_url = f"postgresql://user:password@localhost:5432/employee_db"
engine = create_engine(database_url)
connection = engine.connect()

# %%
# create an employees dataframe
emp_df = pd.read_sql("select * from employees", connection)
emp_df.fillna("NaN")
# Out:
#         emp_no emp_title  birth_date   first_name  last_name sex   hire_date
# 0       473302     s0001   7/25/1953     Hideyuki   Zallocco   M   4/28/1990
# 1       475053     e0002  11/18/1954        Byong  Delgrande   F    9/7/1991
# 2        57444     e0002   1/30/1958        Berry       Babb   F   3/21/1992
# 3       421786     s0001   9/28/1957        Xiong   Verhoeff   M  11/26/1987
# 4       282238     e0003  10/28/1952   Abdelkader    Baumann   F   1/18/1991
# ...        ...       ...         ...          ...        ...  ..         ...
# 300019  464231     s0001   8/14/1958  Constantino    Eastman   M  10/28/1988
# 300020  255832     e0002    5/8/1955       Yuping     Dayang   F   2/26/1995
# 300021   76671     s0001    6/9/1959       Ortrud   Plessier   M   2/24/1988
# 300022  264920     s0001   9/22/1959        Percy   Samarati   F    9/8/1994
# 300023  464503     s0002   5/31/1964       Arvind  Slobodova   M  11/23/1987
#
# [300024 rows x 7 columns]

# %%
# create a histogram for the salaries
salaries_df = pd.read_sql("select * from salaries", connection)
salaries_df.fillna("NaN")
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# create graph with bins to hold salaries
plt.hist(salaries_df["salary"], range = (40000, salaries_df['salary'].max()), color = 'red')

plt.title("Salary Histogram")

plt.xlabel("salary")

plt.ylabel("common salary ranges for employees")
# Out:
# Text(0, 0.5, 'common salary ranges for employees')
